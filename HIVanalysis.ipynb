# %%
import pandas as pd
pd.read_csv("/Users/chris/Desktop/ITU/3rdsem/NA/hiv/DS0001/22140-0001-Data.tsv", sep="\t")
# Out:
# /var/folders/yw/s572_ycn0n5d19g5p1z13l3c0000gn/T/ipykernel_10002/420460504.py:2: DtypeWarning: Columns (2,13,27,28,29,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("/Users/chris/Desktop/ITU/3rdsem/NA/ICPSR_22140_2/DS0001/22140-0001-Data.tsv", sep="\t")
#           RID  SAMPLE  SG  NTYPE  FRSTTYPE  IDKNOWN  LOCAL  RACE  ETHN  SEX  \
# 0           1       1   0      1         1        1      1     4     0    1
# 1           2       1   0      1         1        1      1     4     0    1
# 2           3       1   0      1         3        1      1     4     1    0
# 3           4       1   0      1         1        1      1     5     0    1
# 4           5       1   0      1         3        1      1     4     1    0
# ...       ...     ...  ..    ...       ...      ...    ...   ...   ...  ...
# 49410  143803       2  -9      3         3        1     -9     1    -8    0
# ...
